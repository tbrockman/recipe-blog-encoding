# %% [markdown]
# # recipe-blog-encoding
#
# Hide secret messages in natural-looking recipe blog introductions using neural linguistic steganography.
#
# This notebook lets you try encoding and decoding secrets using the default model (`meta-llama/Llama-3.2-3B`) on a free Colab GPU.
#
# > **Note:** You'll need a [HuggingFace token](https://huggingface.co/settings/tokens) with access to `meta-llama/Llama-3.2-3B` (you may need to accept the [model license](https://huggingface.co/meta-llama/Llama-3.2-3B) first).

# %% [markdown]
# ## Setup

# %%
# !git clone https://github.com/tbrockman/recipe-blog-encoding.git
# %cd recipe-blog-encoding
# !pip install -q torch transformers bitsandbytes accelerate numpy

# %%
import os
from getpass import getpass

if "HF_TOKEN" not in os.environ:
    os.environ["HF_TOKEN"] = getpass("Enter your HuggingFace token: ")

# %% [markdown]
# ## Encode
#
# Hide a secret message inside a recipe blog introduction. Change the `MESSAGE` to whatever you'd like to encode.

# %%
MESSAGE = "attack at dawn"

# !python main.py encode \
  --message "{MESSAGE}" \
  --stego-file stego_output.txt

# %% [markdown]
# ## Decode
#
# Recover the hidden message from the generated text. Uses the same default model and prompt.

# %%
# !python main.py decode --stego-file stego_output.txt

# %% [markdown]
# ## Custom prompt
#
# You can use any prompt — the recipe framing is just the default. Both sides need the exact same prompt to encode/decode.

# %%
CUSTOM_PROMPT = "The best thing about making scrambled eggs is: "
CUSTOM_MESSAGE = "meet me at noon"

# !python main.py encode \
  --message "{CUSTOM_MESSAGE}" \
  --prompt "{CUSTOM_PROMPT}" \
  --stego-file custom_output.txt

# %%
# !python main.py decode \
  --stego-file custom_output.txt \
  --prompt "{CUSTOM_PROMPT}"
